# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

RAW_DATA = "data/raw_data"

acc_df_org = pd.read_csv(os.path.join(RAW_DATA, os.path.join("accepted_2007_to_2018q4.csv", "accepted_2007_to_2018q4.csv")))
rej_df_org = pd.read_csv(os.path.join(RAW_DATA, os.path.join("rejected_2007_to_2018q4.csv", "rejected_2007_to_2018q4.csv")))

print(f"Shape of  acc_df_org {acc_df_org.shape} | rej_df_org {rej_df_org.shape} | total {acc_df_org.shape[0] + rej_df_org.shape[0]}")
# Out:
# Shape of  acc_df_org (2260701, 151) | rej_df_org (27648741, 9) | total 29909442

# %%
acc_df_org
